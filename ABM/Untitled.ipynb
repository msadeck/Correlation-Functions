# %%
#Corr. trial
import numpy as np
from sklearn.neighbors import KDTree
from correlation_package import *

# %%
import numpy as np
from sklearn.neighbors import KDTree

# Tiny 3x3 grid
# 0 = phenotype A, 1 = phenotype B
A = np.array([
    [0, 0, 1],
    [1, 0, 0],
    [0, 1, 1]
])

N = 2          # number of phenotypes
radius = 1.5   # neighborhood radius (covers adjacent cells)
A_series = [A]  # just one snapshot for simplicity

# %%
correlation_matrix_for_snapshot_unordered(A,N, radius, global_normalization=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 correlation_matrix_for_snapshot_unordered(A,N, radius, global_normalization=True)
#
# File ~/Projects/mel_summer/Correlation-Functions/ABM/correlation_package.py:121, in correlation_matrix_for_snapshot_unordered(A, N, radius, global_normalization)
#     107 """
#     108 Compute correlation matrix for a single snapshot using unordered neighbor counts.
#     109
#    (...)
#     118 - corr: N x N correlation matrix
#     119 """
#     120 # Use the unordered counts function
# --> 121 total, avg = counts_matrix_for_snapshot_unordered(A, N, radius)
#     123 n_sites = A.size
#     124 P = np.array([np.sum(A == p) / n_sites for p in range(N)])  # marginal probabilities
#
# File ~/Projects/mel_summer/Correlation-Functions/ABM/correlation_package.py:66, in counts_matrix_for_snapshot_unordered(A, N, radius)
#      64 def counts_matrix_for_snapshot_unordered(A, N, radius):
#      65     pos = {p: np.argwhere(A == p) for p in range(N)}
# ---> 66     trees = {p: KDTree(pos[p]) if len(pos[p])>0 else None for p in range(N)}
#      67     total = np.zeros((N, N), dtype=float)
#      68     avg   = np.zeros((N, N), dtype=float)
#
# NameError: name 'KDTree' is not defined
